# %%
import nltk
import pandas as pd
import re
import numpy as np
import scipy as sp
import sys
from collections import Counter
import matplotlib.pyplot as plt

# %matplotlib notebook

# %%
edges = pd.read_csv('Test.csv')

# %%
edges.rename_axis({'RelationSymbolicName':'Relation','msrc':'Sentences'},axis=1, inplace=True)

# %%
edges['Relation'][0]
# Out:
# 'positive MolSynthesis: CRH --+> cortisol'

# %%
edges['Relation'][0] = re.sub('.*(?<=: )','',edges['Relation'][0])

# %%
edges['Sentences'] = edges['Sentences'].apply(lambda x: re.sub('{.*?}','',x))

# %%
edges
# Out:
#                                         Relation  \
# 0                              CRH --+> cortisol
# 1      positive MolSynthesis: ACTH --+> cortisol
# 2      negative MolSynthesis: cortisol ---| ACTH
# 3            DirectRegulation: cortisol ---> CRH
# 4   negative DirectRegulation: cortisol ---| CRH
# 5       positive DirectRegulation: ACTH --+> CRH
# 6           positive MolTransport: CRH --+> ACTH
# 7                MolTransport: cortisol ---> CRH
# 8               MolTransport: cortisol ---> ACTH
# 9      positive MolTransport: ACTH --+> cortisol
# 10      positive MolTransport: CRH --+> cortisol
#
#                                             Sentences
# 0   ID ID may regulate ID via its effects on ID pe...
# 1   Besides, different types of ID were shown to p...
# 2   Finally, it has been previously shown that ID ...
# 3   Blocking ID-stimulated increases in ID and ID ...
# 4   Blocking ID-stimulated increases in ID and ID ...
# 5   Blocking ID-stimulated increases in ID and ID ...
# 6   ID induces the release of ID from the ID which...
# 7   While ID suppresses the secretion of ID from t...
# 8   ID acts via feedback inhibition of its own sec...
# 9   ID is a ID-sensitive peptide that is released ...
# 10  Nevertheless, ID ID has been postulated to sti...

# %%
words = re.findall(r'\w+', str.lower(edges['Sentences'][2]))
words_frame = pd.DataFrame(words)
s = set(nltk.corpus.stopwords.words('english'))
s.add('id')

# %%
word_count = Counter([x for x in words if x not in s])

# %%
len(words)
# Out:
# 1269

# %%
len(word_count)
# Out:
# 284

# %%
data = pd.DataFrame(word_count.most_common(25))

# %%
data.columns=['Words','Count']

# %%
data.head(20).plot.bar(x=data.head(20)['Words'], title='20 Most Frequent Words', rot = 55)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
data
# Out:
#            Words  Count
# 0     production     48
# 1        context     46
# 2       feedback     21
# 3       negative     14
# 4      synthesis      9
# 5      secretion      9
# 6     stimulates      8
# 7        inhibit      7
# 8      increased      6
# 9         causes      6
# 10          loop      6
# 11      maternal      5
# 12     mechanism      5
# 13      inhibits      5
# 14        normal      5
# 15        levels      5
# 16      suppress      5
# 17       release      4
# 18      decrease      4
# 19          also      4
# 20         would      4
# 21      increase      4
# 22     resulting      4
# 23  accumulation      4
# 24       decline      4

# %%
kwords = list(word_count.keys())
vwords = list(word_count.values())

# %%
df = pd.DataFrame(kwords)

# %%
df['Count'] = vwords

# %%
df.sort_values(by='Count', ascending=False, inplace=True)

# %%
df.boxplot(rot=45)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
data.h
