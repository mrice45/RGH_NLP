# %%
import pandas as pd

# %%
network = pd.read_csv('CFS_entities.csv')

# %%
network[['Name','Alias']]
# Out:
#                    Name                                              Alias
# 0                  ACTH  adrenotropin;Acthon;procortan;ACTH vitoria;ACT...
# 1               activin  activin;activins;activin complexes;activin com...
# 2                   AVP  copeptin;vasopressin-neurophysin 2;vasopin;pre...
# 3       B cell function  plasma B-cell function;pre-B cell function;pre...
# 4              cortisol  11beta,17,21-trihydroxy-Pregn-4-ene-3,20-dione...
# 5                   CRH  adrenocorticotrophin-releasing hormone;preproc...
# 6                 CXCL8  CXCL8;lung giant cell carcinoma-derived chemot...
# 7              dopamine  dihydroxyphenylethylamine;inopin;4-(aminoethyl...
# 8           epinephrine  Renalina;adrenalin in oil;Supranol;L-adrenalin...
# 9              estrogen  oestrogen;[14C]oestrogen;estrogen;estrogenic h...
# 10              ethanol  ethyl alcohol & water, 80%;alcohol vapour;Grai...
# ...

# %%
network[['Name','Alias']].apply(lambda x: ';'.join(x), axis=1)
# Out:
# 0     ACTH;adrenotropin;Acthon;procortan;ACTH vitori...
# 1     activin;activin;activins;activin complexes;act...
# 2     AVP;copeptin;vasopressin-neurophysin 2;vasopin...
# 3     B cell function;plasma B-cell function;pre-B c...
# 4     cortisol;11beta,17,21-trihydroxy-Pregn-4-ene-3...
# 5     CRH;adrenocorticotrophin-releasing hormone;pre...
# 6     CXCL8;CXCL8;lung giant cell carcinoma-derived ...
# 7     dopamine;dihydroxyphenylethylamine;inopin;4-(a...
# 8     epinephrine;Renalina;adrenalin in oil;Supranol...
# 9     estrogen;oestrogen;[14C]oestrogen;estrogen;est...
# 10    ethanol;ethyl alcohol & water, 80%;alcohol vap...
# 11    FSH;follicular-stimulating hormones;human foll...
# 12    FST;follistatin isoform FST317;AL033346;activi...
# 13    GH1;growth hormone fraction;GH-N;somatotropin ...
# 14    glutamate;(2S)-2-Aminopentanedioate;L-alpha-Am...
# 15    GNRH1;HH12;Gonadotrophin-releasing factor;GnRH...
# 16    GNRH2;gonadotropin-releasing hormone 2;5-Histi...
# ...
